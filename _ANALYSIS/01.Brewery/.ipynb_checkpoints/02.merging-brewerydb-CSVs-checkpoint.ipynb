# %%
# Import Dependencies

import pandas as pd
import numpy as np

# %%
# Define File Path for CSVs

brew1 = "../CSVs/BreweryPages/brewery_data_page001-014.csv"
brew2 = "../CSVs/BreweryPages/brewery_data_page015-029.csv"
brew3 = "../CSVs/BreweryPages/brewery_data_page030-044.csv"
brew4 = "../CSVs/BreweryPages/brewery_data_page045-059.csv"
brew5 = "../CSVs/BreweryPages/brewery_data_page060-074.csv"
brew6 = "../CSVs/BreweryPages/brewery_data_page075-089.csv"
brew7 = "../CSVs/BreweryPages/brewery_data_page090-104.csv"
brew8 = "../CSVs/BreweryPages/brewery_data_page105-119.csv"
brew9 = "../CSVs/BreweryPages/brewery_data_page120-134.csv"
brew10 = "../CSVs/BreweryPages/brewery_data_page135-149.csv"
brew11 = "../CSVs/BreweryPages/brewery_data_page150-164.csv"
brew12 = "../CSVs/BreweryPages/brewery_data_page165-179.csv"
brew13 = "../CSVs/BreweryPages/brewery_data_page180-194.csv"
brew14 = "../CSVs/BreweryPages/brewery_data_page195-209.csv"
brew15 = "../CSVs/BreweryPages/brewery_data_page210-224.csv"
brew16 = "../CSVs/BreweryPages/brewery_data_page225-239.csv"
brew17 = "../CSVs/BreweryPages/brewery_data_page240-254.csv"
brew18 = "../CSVs/BreweryPages/brewery_data_page255-260.csv"
brew19 = "../CSVs/BreweryPages/brewery_data_page261.csv"

# %%
# Read in CSVs

brewdf1 = pd.read_csv(brew1)
brewdf2 = pd.read_csv(brew2)
brewdf3 = pd.read_csv(brew3)
brewdf4 = pd.read_csv(brew4)
brewdf5 = pd.read_csv(brew5)
brewdf6 = pd.read_csv(brew6)
brewdf7 = pd.read_csv(brew7)
brewdf8 = pd.read_csv(brew8)
brewdf9 = pd.read_csv(brew9)
brewdf10 = pd.read_csv(brew10)
brewdf11 = pd.read_csv(brew11)
brewdf12 = pd.read_csv(brew12)
brewdf13 = pd.read_csv(brew13)
brewdf14 = pd.read_csv(brew14)
brewdf15 = pd.read_csv(brew15)
brewdf16 = pd.read_csv(brew16)
brewdf17 = pd.read_csv(brew17)
brewdf18 = pd.read_csv(brew18)
brewdf19 = pd.read_csv(brew19)

# %%
# Merge CSVs

brewerydf = pd.concat((brewdf1, brewdf2, brewdf3, brewdf4, brewdf5, brewdf6, brewdf7, brewdf8,
                       brewdf9, brewdf10, brewdf11, brewdf12, brewdf13, 
                        brewdf14, brewdf15, brewdf16, brewdf17, brewdf18, 
                        brewdf19), join="outer")
brewerydf.head()
# Out:
#                    Brewery Name            City       State        Country  \
# 0             4 Seasons Brewery          Lapeer    Michigan  UNITED STATES
# 1              40 North Brewing         Boulder    Colorado  UNITED STATES
# 2             4KD Crick Brewery        Defiance        Ohio  UNITED STATES
# 3  Karl Strauss Brewing Company       San Diego  California  UNITED STATES
# 4                7 Cent Brewery  Gisborne South    Victoria      AUSTRALIA
#
#    Year Established Still in Business? Closed?
# 0              2014                  Y       N
# 1              2011                  Y       N
# 2              2016                  Y       N
# 3              1989                  Y       N
# 4              2012                  Y       N

# %%
## Clean up the Data Frame

# Initial count
brewerydf.count()
# Out:
# Brewery Name          1068
# City                  1068
# State                 1068
# Country               1068
# Year Established      1068
# Still in Business?    1068
# Closed?               1068
# dtype: int64

# %%
# Remove non-USA Breweries

usabrewerydf = brewerydf.loc[(brewerydf["Country"] == "UNITED STATES")]
usabrewerydf.count()
# Out:
# Brewery Name          838
# City                  838
# State                 838
# Country               838
# Year Established      838
# Still in Business?    838
# Closed?               838
# dtype: int64

# %%
# Remove Breweries before 2009

brewerydf2009 = usabrewerydf.loc[(usabrewerydf["Year Established"] >= 2009)]
brewerydf2009.count()
# Out:
# Brewery Name          564
# City                  564
# State                 564
# Country               564
# Year Established      564
# Still in Business?    564
# Closed?               564
# dtype: int64

# %%
# Replace "null" with NaN values

#brewerydfnull = brewerydf2009.replace(['null'], np.nan)
#brewerydfnull.count()

# %%
# Drop all rows with missing information

#cleanbrewerydf = brewerydfnull.dropna(axis=0, how='any')
#cleanbrewerydf.count()

# %%
final_df = brewerydf2009
final_df.head()
# Out:
#         Brewery Name        City       State        Country  Year Established  \
# 0  4 Seasons Brewery      Lapeer    Michigan  UNITED STATES              2014
# 1   40 North Brewing     Boulder    Colorado  UNITED STATES              2011
# 2  4KD Crick Brewery    Defiance        Ohio  UNITED STATES              2016
# 6     7 Mile Brewery  Rio Grande  New Jersey  UNITED STATES              2016
# 7      810 Meadworks      Medina    New York  UNITED STATES              2014
#
#   Still in Business? Closed?
# 0                  Y       N
# 1                  Y       N
# 2                  Y       N
# 6                  Y       N
# 7                  Y       N

# %%
states_df = final_df.groupby(["State"])
states_df.count()
# Out:
#                       Brewery Name  City  Country  Year Established  \
# State
# Alabama                          5     5        5                 5
# Alaska                           2     2        2                 2
# Arizona                         10    10       10                10
# Arkansas                         1     1        1                 1
# California                      69    69       69                69
# Colorado                        39    39       39                39
# Connecticut                      3     3        3                 3
# Delaware                         2     2        2                 2
# District of Columbia             1     1        1                 1
# Florida                         19    19       19                19
# Georgia                          4     4        4                 4
# Hawaii                           6     6        6                 6
# Idaho                            5     5        5                 5
# ...

# %%
# Export Merged & Cleaned CSV

final_df.to_csv("../CSVs/brewerydb_final.csv",
                   encoding="utf-8", index=False, header=True)
